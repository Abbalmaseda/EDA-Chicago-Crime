# %%
import pandas as pd

# %%
df_chicago_crimes = pd.read_csv("../src/data/Chicago_Crimes_2014_to_2017.csv", sep=";")

# %%
df_chicago_data = pd.read_csv("../src/data/Chicago Health Atlas Data Download - Community areas.csv", sep=",")

# %%
df_chicago_crimes.head(5)
# Out:
#    Unnamed: 0        ID Case Number        Date                Block IUCR  \
# 0           3  10508693    HZ250496  05/03/2016   013XX S SAWYER AVE  486
# 1          89  10508695    HZ250409  05/03/2016   061XX S DREXEL AVE  486
# 2         197  10508697    HZ250503  05/03/2016  053XX W CHICAGO AVE  470
# 3         673  10508698    HZ250424  05/03/2016    049XX W FULTON ST  460
# 4         911  10508699    HZ250455  05/03/2016    003XX N LOTUS AVE  820
#
#              Primary Type              Description Location Description  \
# 0                 BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT
# 1                 BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE
# 2  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT               STREET
# 3                 BATTERY                   SIMPLE             SIDEWALK
# 4                   THEFT           $500 AND UNDER            RESIDENCE
#
#    Arrest  ...  Ward  Community Area  FBI Code  X Coordinate  Y Coordinate  \
# ...

# %%
df_chicago_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408122 entries, 0 to 408121
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            408122 non-null  int64
#  1   ID                    408122 non-null  int64
#  2   Case Number           408122 non-null  object
#  3   Date                  408122 non-null  object
#  4   Block                 408122 non-null  object
#  5   IUCR                  408122 non-null  object
#  6   Primary Type          408122 non-null  object
#  7   Description           408122 non-null  object
#  8   Location Description  407855 non-null  object
#  9   Arrest                408122 non-null  bool
#  10  Domestic              408122 non-null  bool
#  11  Beat                  408122 non-null  int64
#  12  District              408122 non-null  float64
#  13  Ward                  408119 non-null  float64
# ...

# %%
df_chicago_crimes.isna().mean() * 100
# Out:
# Unnamed: 0              0.000000
# ID                      0.000000
# Case Number             0.000000
# Date                    0.000000
# Block                   0.000000
# IUCR                    0.000000
# Primary Type            0.000000
# Description             0.000000
# Location Description    0.065422
# Arrest                  0.000000
# Domestic                0.000000
# Beat                    0.000000
# District                0.000000
# Ward                    0.000735
# Community Area          0.000245
# FBI Code                0.000000
# X Coordinate            1.526014
# Y Coordinate            1.526014
# Year                    0.000000
# Updated On              0.000000
# Latitude                1.526014
# Longitude               1.526014
# Location                1.526014
# dtype: float64

# %%
df_chicago_data.head(5)
# Out:
#             Layer            Name  GEOID                     UMP_2012-2016  \
# 0             NaN             NaN    NaN  Unemployment rate (%), 2012-2016
# 1  Community area     Rogers Park    1.0                 8.504513572877206
# 2  Community area    Norwood Park   10.0                5.4095813548225715
# 3  Community area  Jefferson Park   11.0                 7.503843108237212
# 4  Community area     Forest Glen   12.0                 4.552057997239468
#
#                        HDX_2012-2016                       INC_2012-2016  \
# 0  Hardship Index (score), 2012-2016  Median household income, 2012-2016
# 1                 62.972504962864825                  49554.028565890825
# 2                  25.48356985322108                   97173.95208879767
# 3                  38.28131134308272                   84758.01159705805
# 4                 17.079266817084157                  146273.52831758704
#
#                                  POC_2016-2020  \
# ...
